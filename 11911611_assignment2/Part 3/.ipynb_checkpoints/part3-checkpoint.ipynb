# %%
# %matplotlib inline
# %run train.py --input_length 5
# Out:
# C:\Users\stone\PycharmProjects\ai\11911611_assignment2\Part 3\train.py:53: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# Done training.

# %%
# task3 
you can change the input length above.
# Out:
#   Input In [2]
#     you can change the input length above.
#         ^
# SyntaxError: invalid syntax
