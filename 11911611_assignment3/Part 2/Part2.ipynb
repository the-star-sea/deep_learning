# %% [markdown]
# # part2
# U can run the train by below cell.

# %%
# %matplotlib inline
# %run train.py

# %%
from IPython.display import Image

Image(filename = "gan.jpg", width=400, height=400)

# %% [markdown]
# Below is the images sample while training

# %%
Image(filename = "images//0.png", width=400, height=400)

# %%
Image(filename = "images//1000.png", width=400, height=400)

# %%
Image(filename = "images//2000.png", width=400, height=400)

# %%
Image(filename = "images//3000.png", width=400, height=400)

# %%
Image(filename = "images//4000.png", width=400, height=400)

# %%
Image(filename = "images//5000.png", width=400, height=400)

# %%
Image(filename = "images//10000.png", width=400, height=400)

# %%
Image(filename = "images//15000.png", width=400, height=400)

# %%
Image(filename = "images//20000.png", width=400, height=400)

# %%
Image(filename = "images//40000.png", width=400, height=400)

# %%
Image(filename = "images//60000.png", width=400, height=400)

# %%
Image(filename = "images//80000.png", width=400, height=400)

# %%
Image(filename = "images//100000.png", width=400, height=400)

# %%
Image(filename = "images//120000.png", width=400, height=400)

# %%
Image(filename = "images//140000.png", width=400, height=400)

# %%
Image(filename = "images//160000.png", width=400, height=400)

# %%
Image(filename = "images//180000.png", width=400, height=400)

# %%
Image(filename = "images//200000.png", width=400, height=400)

# %%
Image(filename = "images//220000.png", width=400, height=400)

# %%
Image(filename = "images//240000.png", width=400, height=400)

# %%
Image(filename = "images//260000.png", width=400, height=400)

# %%
Image(filename = "images//300000.png", width=400, height=400)

# %%
Image(filename = "images//320000.png", width=400, height=400)

# %%
Image(filename = "images//340000.png", width=400, height=400)

# %% [markdown]
# Below are 9 interpolation photos

# %%
Image(filename = "interpolation/0.png", width=400, height=400)

# %%
Image(filename = "interpolation/1.png", width=400, height=400)

# %%
Image(filename = "interpolation/2.png", width=400, height=400)

# %%
Image(filename = "interpolation/3.png", width=400, height=400)

# %%
Image(filename = "interpolation/4.png", width=400, height=400)

# %%
Image(filename = "interpolation/5.png", width=400, height=400)

# %%
Image(filename = "interpolation/6.png", width=400, height=400)

# %%
Image(filename = "interpolation/7.png", width=400, height=400)

# %%
Image(filename = "interpolation/8.png", width=400, height=400)
