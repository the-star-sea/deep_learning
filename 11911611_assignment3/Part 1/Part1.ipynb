# %% [markdown]
# # part 1
# Run lstm with input length =5,learning rate =0.001,max_norms=10.0 for 400 epoch

# %%
# %matplotlib inline
# %run train.py
# Out:
# C:\Users\stone\PycharmProjects\ai\11911611_assignment3\Part 1\train.py:60: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# Done training.

# %% [markdown]
# Run vrnn with input length =5,learning rate =0.001,max_norms=10.0 for 400 epoch

# %%
# %matplotlib inline
# %run vrnn_train.py
# Out:
# C:\Users\stone\PycharmProjects\ai\11911611_assignment3\Part 1\vrnn_train.py:50: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# Done training.

# %% [markdown]
# As we can see clearly,the lstm's accuracy grows much faster than vrnn and the loss also goes down quicker than vrnn.
